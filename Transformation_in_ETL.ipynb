# %%
Question 1: Define Data Transformation in ETL and explain why it is important.
Definition

Data Transformation is the process of converting extracted data into a clean, consistent, and suitable format before loading it into the target system (such as a database or data warehouse).

Importance
Improves data quality by correcting errors and inconsistencies.
Converts data into a standard format.
Removes duplicate and unnecessary records.
Makes data compatible with the target system.
Supports accurate reporting, analytics, and decision-making.

Example:
Converting dates from DD-MM-YYYY (15-07-2026) to YYYY-MM-DD (2026-07-15) before loading into a database.

Question 2: List any four common activities involved in Data Cleaning.

The following are four common data cleaning activities:

1. Handling Missing Values

Fill missing values using the mean, median, mode, or remove incomplete records.

2. Removing Duplicate Records

Identify and delete duplicate entries to avoid incorrect analysis.

3. Correcting Data Formats

Standardize formats such as dates, phone numbers, currency, and text.

4. Correcting Inconsistent Values

Replace inconsistent values with a common standard.

Example:

M, Male, male → Male
F, Female, female → Female
Question 3: What is the difference between Normalization and Standardization?
Feature	Normalization	Standardization
Definition	Scales data to a fixed range	Converts data to have mean = 0 and standard deviation = 1
Output Range	Usually 0 to 1	No fixed range
Formula	(X − Min) / (Max − Min)	(X − Mean) / Standard Deviation
Outlier Handling	Sensitive to outliers	Less affected by outliers
Best Used When	Data has no significant outliers	Data contains outliers or follows a normal distribution
Example

Original Values:

10, 20, 30, 40

Normalization:

0, 0.33, 0.67, 1

Standardization:
Produces values centered around 0 with a standard deviation of 1.

Question 4: A dataset has missing values in the “Age” column. Suggest two techniques to handle this and explain when they should be used.
Technique 1: Mean/Median Imputation

Replace missing values with:

Mean if the data is normally distributed.
Median if the data contains outliers.

Example:

20, 25, NULL, 30, 35

Median = 27.5

Result:

20, 25, 27.5, 30, 35

Use When:

Only a few values are missing.
Most records should be retained.
Technique 2: Remove Missing Records

Delete rows where the Age value is missing.

Use When:

Only a small percentage of rows have missing values.
Missing data cannot be estimated reliably.
Question 5: Convert the following inconsistent “Gender” entries into a standardized format (“Male”, “Female”).
Input
["M", "male", "F", "Female", "MALE", "f"]
Standardized Output
["Male", "Male", "Female", "Female", "Male", "Female"]
Mapping Used
Original	Standardized
M	Male
male	Male
MALE	Male
F	Female
Female	Female
f	Female
Question 6: What is One-Hot Encoding? Give an example with the categories: “Red, Blue, Green”.
Definition

One-Hot Encoding is a technique used to convert categorical data into binary (0 or 1) columns so that machine learning algorithms can process it.

Example

Original Data:

Color
Red
Blue
Green

After One-Hot Encoding:

Color	Red	Blue	Green
Red	1	0	0
Blue	0	1	0
Green	0	0	1

Each category gets its own column, and the corresponding category is marked with 1, while the others are 0.

Question 7: Explain the difference between Data Integration and Data Mapping in ETL.
Data Integration	Data Mapping
Combines data from multiple sources into one unified dataset.	Defines how fields from the source correspond to fields in the target system.
Focuses on merging data.	Focuses on matching and transforming data fields.
Uses multiple databases or files.	Uses source-to-target column relationships.
Goal is a single, unified view of data.	Goal is accurate data transfer.
Example

Data Integration:
Combine customer information from:

CRM system
Sales database
Marketing platform

into one customer data warehouse.

Data Mapping:

Source Field	Target Field
Cust_ID	Customer_ID
Cust_Name	Customer_Name
DOB	Date_of_Birth
Question 8: Explain why Z-score Standardization is preferred over Min-Max Scaling when outliers exist.
Z-score Standardization

Formula:

Z=
Standard Deviation
X−Mean
	​


It transforms data so that:

Mean = 0
Standard deviation = 1
Min-Max Scaling

Formula:

Max−Min
X−Min
	​


It scales data between 0 and 1.

Why Z-score is Preferred with Outliers
Less sensitive to outliers: Z-score uses the mean and standard deviation, so extreme values have less impact on the scaling of most observations.
Preserves distribution: It maintains the relative spread of the data better than Min-Max Scaling.
Suitable for many algorithms: It works well for algorithms that assume normally distributed data, such as Logistic Regression and Support Vector Machines.
Example

Dataset:

10, 12, 15, 18, 500
Min-Max Scaling: The value 500 becomes the maximum, causing the other values to be compressed very close to 0.
Z-score Standardization: The outlier still has a large Z-score, but the remaining values retain more meaningful differences.
